# %%
import os
import re
import math
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# !pip -q install pymorphy2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 67.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done

# %%
import nltk

from nltk.corpus import stopwords
from pymorphy2 import MorphAnalyzer
from pymystem3 import Mystem

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# !wget https://getfile.dokpub.com/yandex/get/https://disk.yandex.ru/d/HwrqIBfc4gXRMQ/food-dataset-ru.csv
# Out:
# --2023-06-30 19:42:25--  https://getfile.dokpub.com/yandex/get/https://disk.yandex.ru/d/HwrqIBfc4gXRMQ/food-dataset-ru.csv
# Resolving getfile.dokpub.com (getfile.dokpub.com)... 142.132.255.217
# Connecting to getfile.dokpub.com (getfile.dokpub.com)|142.132.255.217|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://downloader.disk.yandex.ru/disk/99a372837a20d9583aacf999cca04c66eab78d33f0c983fdc012b0b19f0af159/649f6861/xw5Ld4ahZ3PXthbshI9L6XH8J5jyn8ebkeiO1sv7L-A_zWAfaXOCgzOjU9saaKkKBMf3W20PsRL97S6mz1dQFA%3D%3D?uid=0&filename=food-dataset-ru.csv&disposition=attachment&hash=jwBgKhoRZnhy3Vo2lwXI7M/NsSuFKWrDxrJ47U6qkrLZlz61neDDkjC/X/Kd2QG2q/J6bpmRyOJonT3VoXnDag%3D%3D%3A/food-dataset-ru.csv&limit=0&content_type=text%2Fplain&owner_uid=1632007365&fsize=66912433&hid=867f6ecc62376fca5dcaad437eaf35c1&media_type=spreadsheet&tknv=v2 [following]
# --2023-06-30 19:42:25--  https://downloader.disk.yandex.ru/disk/99a372837a20d9583aacf999cca04c66eab78d33f0c983fdc012b0b19f0af159/649f6861/xw5Ld4ahZ3PXthbshI9L6XH8J5jyn8ebkeiO1sv7L-A_zWAfaXOCgzOjU9saaKkKBMf3W20PsRL97S6mz1dQFA%3D%3D?uid=0&filename=food-dataset-ru.csv&disposition=attachment&hash=jwBgKhoRZnhy3Vo2lwXI7M/NsSuFKWrDxrJ47U6qkrLZlz61neDDkjC/X/Kd2QG2q/J6bpmRyOJonT3VoXnDag%3D%3D%3A/food-dataset-ru.csv&limit=0&content_type=text%2Fplain&owner_uid=1632007365&fsize=66912433&hid=867f6ecc62376fca5dcaad437eaf35c1&media_type=spreadsheet&tknv=v2
# Resolving downloader.disk.yandex.ru (downloader.disk.yandex.ru)... 77.88.21.127, 2a02:6b8::2:127
# Connecting to downloader.disk.yandex.ru (downloader.disk.yandex.ru)|77.88.21.127|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s296vlx.storage.yandex.net/rdisk/99a372837a20d9583aacf999cca04c66eab78d33f0c983fdc012b0b19f0af159/649f6861/xw5Ld4ahZ3PXthbshI9L6XH8J5jyn8ebkeiO1sv7L-A_zWAfaXOCgzOjU9saaKkKBMf3W20PsRL97S6mz1dQFA==?uid=0&filename=food-dataset-ru.csv&disposition=attachment&hash=jwBgKhoRZnhy3Vo2lwXI7M/NsSuFKWrDxrJ47U6qkrLZlz61neDDkjC/X/Kd2QG2q/J6bpmRyOJonT3VoXnDag%3D%3D%3A/food-dataset-ru.csv&limit=0&content_type=text%2Fplain&owner_uid=1632007365&fsize=66912433&hid=867f6ecc62376fca5dcaad437eaf35c1&media_type=spreadsheet&tknv=v2&rtoken=ulvflWCxFkWt&force_default=no&ycrid=na-128f122032265ad242467ff1a86d0b6b-downloader4f&ts=5ff615e721a40&s=a94ee1275ff6b1419535482dc7085292e789b0abdfca96acef2759889f76171b&pb=U2FsdGVkX1-lYqEuAwaIk4QDXTcnY7wUnTZf4BVHHu1MfN9yJ4IWCV3XRD9GXKp_gxfoHpYhQL8RnWdGeDyrx6KzNya4htiPwxFXYOnpJlM [following]
# --2023-06-30 19:42:26--  https://s296vlx.storage.yandex.net/rdisk/99a372837a20d9583aacf999cca04c66eab78d33f0c983fdc012b0b19f0af159/649f6861/xw5Ld4ahZ3PXthbshI9L6XH8J5jyn8ebkeiO1sv7L-A_zWAfaXOCgzOjU9saaKkKBMf3W20PsRL97S6mz1dQFA==?uid=0&filename=food-dataset-ru.csv&disposition=attachment&hash=jwBgKhoRZnhy3Vo2lwXI7M/NsSuFKWrDxrJ47U6qkrLZlz61neDDkjC/X/Kd2QG2q/J6bpmRyOJonT3VoXnDag%3D%3D%3A/food-dataset-ru.csv&limit=0&content_type=text%2Fplain&owner_uid=1632007365&fsize=66912433&hid=867f6ecc62376fca5dcaad437eaf35c1&media_type=spreadsheet&tknv=v2&rtoken=ulvflWCxFkWt&force_default=no&ycrid=na-128f122032265ad242467ff1a86d0b6b-downloader4f&ts=5ff615e721a40&s=a94ee1275ff6b1419535482dc7085292e789b0abdfca96acef2759889f76171b&pb=U2FsdGVkX1-lYqEuAwaIk4QDXTcnY7wUnTZf4BVHHu1MfN9yJ4IWCV3XRD9GXKp_gxfoHpYhQL8RnWdGeDyrx6KzNya4htiPwxFXYOnpJlM
# Resolving s296vlx.storage.yandex.net (s296vlx.storage.yandex.net)... 5.45.238.104, 2a02:6b8:c34:74:0:41af:c968:1daa
# Connecting to s296vlx.storage.yandex.net (s296vlx.storage.yandex.net)|5.45.238.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66912433 (64M) [text/plain]
# Saving to: ‘food-dataset-ru.csv’
#
# food-dataset-ru.csv 100%[===================>]  63.81M  45.6MB/s    in 1.4s
#
# 2023-06-30 19:42:28 (45.6 MB/s) - ‘food-dataset-ru.csv’ saved [66912433/66912433]

# %%
df_items = pd.read_csv('food-dataset-ru.csv')

# %%
df_items.head()
# Out:
#                             name  \
# 0            Завтрак для ленивых
# 1              Гречневый завтрак
# 2                Завтрак детства
# 3      Полный английский завтрак
# 4  Французские гренки к завтраку
#
#                                                 text  \
# 0  В широкую миску выложить творог, добавить яйцо...
# 1  Гречку промыть, залить 2 стаканами кипятка, по...
# 2  Морковь и зеленое яблоко натереть на средней т...
# 3  Разогреть духовку до 180 градусов, а сковороду...
# 4  Смешать яйцо с молоком. Посолить. Обмакнуть ку...
#
#                                           ingredient  \
# 0  Куриное яйцо: 1 штука, Мягкий творог: 200 г, П...
# 1  Гречневая крупа: 1 стакан, Рубленая петрушка: ...
# 2  Морковь: 1 штука, Яблоко: 1 штука, Апельсины: ...
# 3  Куриное яйцо: 2 штуки, Свиные сосиски: 2 штуки...
# 4  Батон: 3 куска, Молоко: 2 столовые ложки, Кури...
#
#                                               energy          time_cook  \
# 0  Калорий 87 ккал, Белки 8 грамм, Жиры 2 грамм, ...      Русская кухня
# 1  Калорий 284 ккал, Белки 6 грамм, Жиры 11 грамм...      Русская кухня
# 2  Калорий 623 ккал, Белки 13 грамм, Жиры 22 грам...      Русская кухня
# 3  Калорий 907 ккал, Белки 26 грамм, Жиры 75 грам...   Британская кухня
# 4  Калорий 519 ккал, Белки 16 грамм, Жиры 29 грам...  Французская кухня
#
#       type_kitchen                                               link    label
# 0         15 минут  https://eda.ru/recepty/zavtraki/zavtrak-dlja-l...  Завтрак
# 1  1 час  20 минут  https://eda.ru/recepty/zavtraki/grechnevij-zav...  Завтрак
# 2          5 минут  https://eda.ru/recepty/zavtraki/zavtrak-detstv...  Завтрак
# 3         30 минут  https://eda.ru/recepty/zavtraki/polnyy-angliys...  Завтрак
# 4         10 минут  https://eda.ru/recepty/zavtraki/francuzskie-gr...  Завтрак

# %%
def preprocessing(df_items):
    text_list = []
    stopwords_ru = stopwords.words("russian")
    mystem = Mystem()
    for i in range(df_items.shape[0]):
        text = " ".join(df_items.iloc[i, :5].values)
        text = text.lower()
        text = re.sub(r'\([^()]*\)', '', text)
        text = re.sub(r'[^а-яё]', ' ', text)
        text = re.sub(" +", " ", text)

        tokens = mystem.lemmatize(text)
        text = " ".join([token for token in tokens\
                         if not token in stopwords_ru and token != " " and len(token) > 1])

        if i % 500 == 0:
            print(f"{i} / {df_items.shape[0]}")
        text_list.append(text)

    return text_list

# %%
text_list = preprocessing(df_items)
# Out:
# 0 / 37638
# 500 / 37638
# 1000 / 37638
# 1500 / 37638
# 2000 / 37638
# 2500 / 37638
# 3000 / 37638
# 3500 / 37638
# 4000 / 37638
# 4500 / 37638
# 5000 / 37638
# 5500 / 37638
# 6000 / 37638
# 6500 / 37638
# 7000 / 37638
# 7500 / 37638
# 8000 / 37638
# 8500 / 37638
# 9000 / 37638
# 9500 / 37638
# 10000 / 37638
# 10500 / 37638
# 11000 / 37638
# 11500 / 37638
# 12000 / 37638
# 12500 / 37638
# 13000 / 37638
# 13500 / 37638
# 14000 / 37638
# 14500 / 37638
# 15000 / 37638
# 15500 / 37638
# 16000 / 37638
# 16500 / 37638
# 17000 / 37638
# 17500 / 37638
# 18000 / 37638
# 18500 / 37638
# 19000 / 37638
# 19500 / 37638
# 20000 / 37638
# 20500 / 37638
# 21000 / 37638
# 21500 / 37638
# 22000 / 37638
# 22500 / 37638
# 23000 / 37638
# 23500 / 37638
# 24000 / 37638
# 24500 / 37638
# 25000 / 37638
# 25500 / 37638
# 26000 / 37638
# 26500 / 37638
# 27000 / 37638
# 27500 / 37638
# 28000 / 37638
# 28500 / 37638
# 29000 / 37638
# 29500 / 37638
# 30000 / 37638
# 30500 / 37638
# 31000 / 37638
# 31500 / 37638
# 32000 / 37638
# 32500 / 37638
# 33000 / 37638
# 33500 / 37638
# 34000 / 37638
# 34500 / 37638
# 35000 / 37638
# 35500 / 37638
# 36000 / 37638
# 36500 / 37638
# 37000 / 37638
# 37500 / 37638

# %%
text_list[2]
# Out:
# 'завтрак детство морковь зеленый яблоко натирать средний терка апельсин снимать цедра половинка выдавливать сок второй нарезать небольшой кусочек смешать яблоко морковь апельсин изюм орех заправлять сок мед добавлять корица морковь штука яблоко штука апельсин штука изюм мед чайный ложка орех молотый корица вкус калория ккал белок грамм жир грамм углевод грамм русский кухня'

# %%
vectorizer = TfidfVectorizer()
items_vec = vectorizer.fit_transform(text_list)

# %%
def get_recommendation(text, vectorizer, items_vec):
    stopwords_ru = stopwords.words("russian")
    mystem = Mystem()

    text = text.lower()
    text = re.sub(r'\([^()]*\)', '', text)
    text = re.sub(r'[^а-яё]', ' ', text)
    text = re.sub(" +", " ", text)

    tokens = mystem.lemmatize(text)
    text = " ".join([token for token in tokens\
                    if not token in stopwords_ru and token != " " and len(token) > 1])
    text = vectorizer.transform([text])

    rating = cosine_similarity(items_vec, text).reshape(-1)
    rating_arg = np.argsort(rating)[::-1]

    return rating_arg.tolist()

# %% [markdown]
# Первая рекомендация

# %%
text = " ".join(df_items.iloc[34529, :5].values)
rating = get_recommendation(text, vectorizer, items_vec)
df_items.iloc[rating].head()
# Out:
#                                          name  \
# 34529         Разноцветные американские кукис
# 30453              Печенье с шоколадным драже
# 35946  Овсяное печенье с шоколадом и фундуком
# 34673         Печенье с тремя видами шоколада
# 34497         Домашнее пряное овсяное печенье
#
#                                                     text  \
# 34529  Разогрейте духовку до 180 градусов. Сливочное ...
# 30453  Смешать в миске размягченное масло и сахар до ...
# 35946  Разогрейте духовку до 180 градусов. Возьмите м...
# 34673  Разогреть духовку до 180 градусов. Смазать про...
# 34497  Нагреть духовку до 180 градусов. Застелить про...
#
#                                               ingredient  \
# 34529  Сливочное масло: 120 г, Ванилин: 1 чайная ложк...
# 30453  Сливочное масло: 200 г, Тростниковый сахар: 1 ...
# 35946  Овсяная мука: 150 г, Овсяные хлопья: 60 г, Сол...
# 34673  Сливочное масло: 80 г, Тростниковый сахар: 180...
# 34497  Пшеничная мука: 245 г, Овсяные хлопья: 300 г, ...
#
#                                                   energy           time_cook  \
# 34529  Калорий 2672 ккал, Белки 32 грамм, Жиры 134 гр...  Американская кухня
# 30453  Калорий 366 ккал, Белки 5 грамм, Жиры 20 грамм...   Европейская кухня
# 35946  Калорий 3484 ккал, Белки 54 грамм, Жиры 209 гр...   Европейская кухня
# 34673  Калорий 2816 ккал, Белки 35 грамм, Жиры 129 гр...   Европейская кухня
# 34497  Калорий 2581 ккал, Белки 39 грамм, Жиры 113 гр...   Европейская кухня
#
#       type_kitchen                                               link    label
# 34529        1 час  https://eda.ru/recepty/vypechka-deserty/raznoc...  Выпечка
# 30453     25 минут  https://eda.ru/recepty/vypechka-deserty/pechen...  Выпечка
# 35946        1 час  https://eda.ru/recepty/vypechka-deserty/ovsjan...  Выпечка
# 34673        1 час  https://eda.ru/recepty/vypechka-deserty/pechen...  Выпечка
# 34497     40 минут  https://eda.ru/recepty/vypechka-deserty/domash...  Выпечка

# %% [markdown]
# Вторая рекомендация

# %%
text = " ".join(df_items.iloc[12621, :5].values)
rating = get_recommendation(text, vectorizer, items_vec)
df_items.iloc[rating].head()
# Out:
#                                        name  \
# 12621               Говядина в пяти специях
# 25303    Маринад с пятью специями и хересом
# 27728  Щи с телятиной, курицей и лимонником
# 10626        Говядина в соусе «Пять специй»
# 12991                         Копченая рыба
#
#                                                     text  \
# 12621  Куриные и свиные кости залить кипятком (5 л), ...
# 25303  Подготовить все ингредиенты. Поместить в миску...
# 27728  Телячьи кости и куриные крылья залить пятью ли...
# 10626  Измельченные чеснок, лук, чили и тертый имбирь...
# 12991  Филе трески замариновать на полчаса в смеси со...
#
#                                               ingredient  \
# 12621  Куриные кости : 1 кг, Свиные кости: 1 кг, Имби...
# 25303  Соевый соус: ¼ стакана, Сухой херес: ¼ стакана...
# 27728  Телячьи кости: 1 кг, Куриные крылья: 1 кг, Бел...
# 10626  Оливковое масло: 65 мл, Чеснок: 6 зубчиков, Пе...
# 12991  Филе трески: 600 г, Соевый соус: 30 мл, Херес:...
#
#                                                   energy          time_cook  \
# 12621  Калорий 1178 ккал, Белки 68 грамм, Жиры 82 гра...  Европейская кухня
# 25303  Калорий 152 ккал, Белки 2 грамм, Жиры 12 грамм...  Европейская кухня
# 27728  Калорий 600 ккал, Белки 57 грамм, Жиры 25 грам...      Русская кухня
# 10626  Калорий 642 ккал, Белки 51 грамм, Жиры 42 грам...    Китайская кухня
# 12991  Калорий 892 ккал, Белки 19 грамм, Жиры 84 грам...  Европейская кухня
#
#       type_kitchen                                               link  \
# 12621     45 минут  https://eda.ru/recepty/osnovnye-blyuda/govjadi...
# 25303     30 минут  https://eda.ru/recepty/sousy-marinady/marinad-...
# 27728       3 часа  https://eda.ru/recepty/supy/schi-s-teljatinoj-...
# 10626       2 часа  https://eda.ru/recepty/osnovnye-blyuda/govjadi...
# 12991        1 час  https://eda.ru/recepty/osnovnye-blyuda/kopchen...
#
#                 label
# 12621  Основное блюдо
# 25303            Соус
# 27728             Суп
# 10626  Основное блюдо
# 12991  Основное блюдо

# %% [markdown]
# Третья рекомендация

# %%
text = " ".join(df_items.iloc[6177, :5].values)
rating = get_recommendation(text, vectorizer, items_vec)
df_items.iloc[rating].head()
# Out:
#                                              name  \
# 6177                     Форшмак «Дружба народов»
# 5927                             Масло из селедки
# 25975        Суп с шампиньонами и плавленым сыром
# 25696                     Суп из плавленых сырков
# 12162  Куриные рубленые котлеты с плавленым сыром
#
#                                                     text  \
# 6177   Почистить селедку, или купить готовое филе в м...
# 5927   Взять сельдь. Очистить от плавников, головы, к...
# 25975  Нарезать шампиньоны и лук. Добавить сметану. О...
# 25696  Вскипятить в кастрюле 2 л воды, добавить очище...
# 12162  Куриное филе нарезать средними кубиками. Морко...
#
#                                               ingredient  \
# 6177   Морковь: 1 штука, Плавленый сырок: 3 штуки, Фи...
# 5927   Сливочное масло: 200 г, Слабосоленая сельдь: 4...
# 25975  Шампиньоны: 200 г, Курица: 300 г, Картофель: 2...
# 25696  Корень сельдерея: 1 штука, Плавленый сырок: 2 ...
# 12162  Куриное филе: 500 г, Плавленый сырок: 2 штуки,...
#
#                                                   energy          time_cook  \
# 6177   Калорий 277 ккал, Белки 21 грамм, Жиры 14 грам...  Европейская кухня
# 5927   Калорий 1087 ккал, Белки 59 грамм, Жиры 85 гра...      Русская кухня
# 25975  Калорий 300 ккал, Белки 20 грамм, Жиры 16 грам...  Французская кухня
# 25696  Калорий 405 ккал, Белки 20 грамм, Жиры 18 грам...  Французская кухня
# 12162  Калорий 767 ккал, Белки 50 грамм, Жиры 48 грам...  Европейская кухня
#
#       type_kitchen                                               link  \
# 6177      20 минут  https://eda.ru/recepty/zakuski/forshmak-druzhb...
# 5927     31 минута  https://eda.ru/recepty/zakuski/maslo-iz-seledk...
# 25975        1 час  https://eda.ru/recepty/supy/sup-s-shampinonami...
# 25696     25 минут  https://eda.ru/recepty/supy/sup-iz-plavlenih-s...
# 12162     30 минут  https://eda.ru/recepty/osnovnye-blyuda/kurinie...
#
#                 label
# 6177          Закуска
# 5927          Закуска
# 25975             Суп
# 25696             Суп
# 12162  Основное блюдо

# %% [markdown]
# Четвертая рекомендация

# %%
text = "Ризотто"
rating = get_recommendation(text, vectorizer, items_vec)
df_items.iloc[rating].head()
# Out:
#                                               name  \
# 20125                   Яблочное ризотто с беконом
# 20101       Ризотто с белыми грибами и пармезаном.
# 20134  Ризотто с соусом песто и кедровыми орешками
# 20114                 Ванильное ризотто с арахисом
# 20165                 Веганское ризотто со свеклой
#
#                                                     text  \
# 20125  Очистить и нарезать лук мелкими дольками. Наре...
# 20101  В сотейнике на оливковом масле обжариваем лук-...
# 20134  Для приготовления соуса песто смешать листья б...
# 20114  Поставить молоко греться на плиту, добавив туд...
# 20165  Готовить присыпку для ризотто. Обжарить на ско...
#
#                                               ingredient  \
# 20125  Рис для ризотто: 150 г, Яблочный сок: 500 мл, ...
# 20101  Рис: 70 г, Оливковое масло: 20 мл, Сливочное м...
# 20134  Оливковое масло: 9 столовых ложек, Жемчужный л...
# 20114  Молоко: 600 мл, Рис для ризотто: 100 г, Ваниль...
# 20165  Рис: 320 г, Овощной бульон: 600 мл, Чеснок: 1 ...
#
#                                                   energy          time_cook  \
# 20125  Калорий 626 ккал, Белки 12 грамм, Жиры 40 грам...  Итальянская кухня
# 20101  Калорий 418 ккал, Белки 4 грамм, Жиры 38 грамм...  Итальянская кухня
# 20134  Калорий 906 ккал, Белки 16 грамм, Жиры 62 грам...  Итальянская кухня
# 20114  Калорий 1027 ккал, Белки 33 грамм, Жиры 39 гра...     Каши на молоке
# 20165  Калорий 2175 ккал, Белки 58 грамм, Жиры 34 гра...  Европейская кухня
#
#       type_kitchen                                               link    label
# 20125        1 час  https://eda.ru/recepty/rizotto/yablochnoe-rizo...  Ризотто
# 20101     35 минут  https://eda.ru/recepty/rizotto/rizotto-s-belym...  Ризотто
# 20134     25 минут  https://eda.ru/recepty/rizotto/rizotto-s-souso...  Ризотто
# 20114     40 минут  https://eda.ru/recepty/rizotto/vanilnoe-rizott...  Ризотто
# 20165     25 минут  https://eda.ru/recepty/rizotto/veganskoe-rizot...  Ризотто

# %% [markdown]
# Пятая рекомендация

# %%
text = "Блинчики с вараньем"
rating = get_recommendation(text, vectorizer, items_vec)
df_items.iloc[rating].head()
# Out:
#                                                     name  \
# 17821         Картофельные блинчики с йогуртом и зеленью
# 5648     Блинчики с ветчиной, яйцами и сыром в панировке
# 35179  Блинчики с ветчиной под хрустящей сырной корочкой
# 16871                    Блинчики с начинкой в панировке
# 33447                         Блинчики с заварным кремом
#
#                                                     text  \
# 17821  Картофель вымыть, почистить и натереть на круп...
# 5648   Для приготовления теста: муку смешать с двумя ...
# 35179  Растопите 2 столовые ложки масла и дайте ему н...
# 16871  Муку просеиваем, смешиваем с молоком, 4 яйцами...
# 33447  Сделать тесто из 200 г муки, 500 мл молока, 2 ...
#
#                                               ingredient  \
# 17821  Куриное яйцо: 2 штуки, Пшеничная мука: 3 столо...
# 5648   Пшеничная мука: 200 г, Куриное яйцо: 8 штук, М...
# 35179  Сливочное масло: 150 г, Пшеничная мука: 125 г,...
# 16871  Молоко: 750 мл, Куриное яйцо: 10 штук, Пшеничн...
# 33447  Молоко: 1,1 л, Пшеничная мука: 250 г, Куриное ...
#
#                                                   energy          time_cook  \
# 17821  Калорий 282 ккал, Белки 10 грамм, Жиры 15 грам...  Европейская кухня
# 5648   Калорий 1069 ккал, Белки 61 грамм, Жиры 66 гра...      Русская кухня
# 35179  Калорий 494 ккал, Белки 19 грамм, Жиры 42 грам...  Французская кухня
# 16871  Калорий 621 ккал, Белки 35 грамм, Жиры 38 грам...      Русская кухня
# 33447  Калорий 965 ккал, Белки 22 грамм, Жиры 41 грам...  Французская кухня
#
#           type_kitchen                                               link  \
# 17821         35 минут  https://eda.ru/recepty/osnovnye-blyuda/kartofe...
# 5648          25 минут  https://eda.ru/recepty/zakuski/blinchiki-s-vet...
# 35179  1 час  20 минут  https://eda.ru/recepty/vypechka-deserty/blinch...
# 16871  1 час  40 минут  https://eda.ru/recepty/osnovnye-blyuda/blinchi...
# 33447            1 час  https://eda.ru/recepty/vypechka-deserty/blinch...
#
#                 label
# 17821  Основное блюдо
# 5648          Закуска
# 35179         Выпечка
# 16871  Основное блюдо
# 33447         Выпечка
