# %%
import os
import re
import math
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torchvision.transforms as transforms
import torch.nn.functional as F
import torch.cuda.amp as amp
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.optim import lr_scheduler

import tensorflow as tf

from tqdm import tqdm
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import f1_score
from sklearn.metrics.pairwise import cosine_similarity

# %%
# !pip install -q transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 63.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 26.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 114.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.8 MB/s eta 0:00:00

# %%
from transformers import BertConfig, BertForSequenceClassification, BertTokenizer

# %%
# !nvidia-smi
# Out:
# Thu Jun 29 13:17:45 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Model

# %%
config = {
    "architectures": [
      "BertForPreTraining"
    ],
    "attention_probs_dropout_prob": 0.1,
    "emb_size": 312,
    "gradient_checkpointing": False,
    "hidden_act": "gelu",
    "hidden_dropout_prob": 0.1,
    "hidden_size": 312,
    "initializer_range": 0.02,
    "intermediate_size": 600,
    "layer_norm_eps": 1e-12,
    "max_position_embeddings": 2048,
    "model_type": "bert",
    "num_attention_heads": 12,
    "num_hidden_layers": 3,
    "pad_token_id": 0,
    "position_embedding_type": "absolute",
    "torch_dtype": "float32",
    "transformers_version": "4.30.2",
    "type_vocab_size": 2,
    "use_cache": True,
    "vocab_size": 83828
}

# %%
model = BertForSequenceClassification(BertConfig(**config))
model.classifier = nn.Linear(312, 13)

model = model.cuda()
model.load_state_dict(torch.load("bert-food-cls.pth"))

model = model.bert
model.eval()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(83828, 312, padding_idx=0)
#     (position_embeddings): Embedding(2048, 312)
#     (token_type_embeddings): Embedding(2, 312)
#     (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-2): 3 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=312, out_features=312, bias=True)
#             (key): Linear(in_features=312, out_features=312, bias=True)
#             (value): Linear(in_features=312, out_features=312, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=312, out_features=312, bias=True)
#             (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=312, out_features=600, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=600, out_features=312, bias=True)
#           (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=312, out_features=312, bias=True)
#     (activation): Tanh()
#   )
# )

# %% [markdown]
# ## Data embeddings

# %%
tokenizer = BertTokenizer.from_pretrained("cointegrated/rubert-tiny2")
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/401 [00:00<?, ?B/s]

# %%
df_items = pd.read_csv("food-dataset-full.csv")

# %%
def preproccesing(text, tokenizer):
    """
    Предобработка входного текста
    """
    text = tokenizer(text, add_special_tokens=True, max_length=256,
                  padding='max_length', truncation=True, return_tensors='pt')
    return text

# %%
# Получаем векторные представления каждого продукта
items_embed = []
for i in range(df_items.shape[0]):
    text = " ".join(df_items.iloc[i, [0, 2, 3, 4, 5]].values.tolist())
    text = preproccesing(text, tokenizer)

    text['input_ids'] = text['input_ids'].cuda()
    text['token_type_ids'] = text['token_type_ids'].cuda()
    text['attention_mask'] = text['attention_mask'].cuda()

    with torch.no_grad():
        out = model(**text)

    items_embed.append(out.last_hidden_state[:, 0, :].cpu().numpy())

# %% [markdown]
# ## Recommedation

# %%
def get_recommendation(text_tokens, model, items, df_items):
    """
    Вычисления схожих продуктов для рекомендации
    """
    text_tokens['input_ids'] = text_tokens['input_ids'].cuda()
    text_tokens['token_type_ids'] = text_tokens['token_type_ids'].cuda()
    text_tokens['attention_mask'] = text_tokens['attention_mask'].cuda()

    with torch.no_grad():
        out = model(**text_tokens)
        out = out.last_hidden_state[:, 0, :].cpu().numpy()

    rating = []
    for i in range(len(items)):
        rating.append(cosine_similarity(items[i], out).reshape(-1)[0])
    rating_arg = np.argsort(rating)[::-1]

    return rating_arg.tolist()

# %% [markdown]
# Первая рекомендация

# %%
idx = np.random.randint(df_items.shape[0])
text_input = " ".join(df_items.iloc[idx, [0, 2, 3, 4, 5]].values.tolist())
text_input = preproccesing(text_input, tokenizer)
df_items.iloc[[idx]].head()
# Out:
#                                   name  \
# 34529  Разноцветные американские кукис
#
#                                                     text  \
# 34529  Разогрейте духовку до 180 градусов. Сливочное ...
#
#                                               ingredient  \
# 34529  Сливочное масло: 120 г, Ванилин: 1 чайная ложк...
#
#                                                   energy           time_cook  \
# 34529  Калорий 2672 ккал, Белки 32 грамм, Жиры 134 гр...  Американская кухня
#
#       type_kitchen    label
# 34529        1 час  Выпечка

# %%
rating = get_recommendation(text_input, model, items_embed, df_items)
df_items.iloc[rating].head()
# Out:
#                                       name  \
# 34529      Разноцветные американские кукис
# 33568  Кукисы с кусочками шоколада и М&М’s
# 30062            Сметанный пирог с малиной
# 32003          Ананасовый пирог-перевертыш
# 32536       Капкейки с шоколадной глазурью
#
#                                                     text  \
# 34529  Разогрейте духовку до 180 градусов. Сливочное ...
# 33568  Размягченное масло взбить с сахаром до белой п...
# 30062  Яйца с сахаром взбить миксером на большой скор...
# 32003  Разогреть духовку до 180 градусов. В чаше микс...
# 32536  Сахар и ванильный сахар растереть с маслом. До...
#
#                                               ingredient  \
# 34529  Сливочное масло: 120 г, Ванилин: 1 чайная ложк...
# 33568  Сливочное масло: 150 г, Тростниковый сахар: 1,...
# 30062  Сметана: 200 г, Сахар: 250 г, Пшеничная мука: ...
# 32003  Сливочное масло: 230 г, Мед: 1,5 столовых ложе...
# 32536  Куриное яйцо: 2 штуки, Кефир: 200 мл, Пшенична...
#
#                                                   energy           time_cook  \
# 34529  Калорий 2672 ккал, Белки 32 грамм, Жиры 134 гр...  Американская кухня
# 33568  Калорий 366 ккал, Белки 5 грамм, Жиры 15 грамм...     Армянская кухня
# 30062  Калорий 599 ккал, Белки 11 грамм, Жиры 24 грам...   Европейская кухня
# 32003  Калорий 768 ккал, Белки 7 грамм, Жиры 35 грамм...   Европейская кухня
# 32536  Калорий 218 ккал, Белки 5 грамм, Жиры 9 грамм,...  Американская кухня
#
#       type_kitchen    label
# 34529        1 час  Выпечка
# 33568        1 час  Выпечка
# 30062       2 часа  Выпечка
# 32003        1 час  Выпечка
# 32536        1 час  Выпечка

# %% [markdown]
# Вторая рекомендация

# %%
idx = np.random.randint(df_items.shape[0])
text_input = " ".join(df_items.iloc[idx, [0, 2, 3, 4, 5]].values.tolist())
text_input = preproccesing(text_input, tokenizer)
df_items.iloc[[idx]].head()
# Out:
#                           name  \
# 12621  Говядина в пяти специях
#
#                                                     text  \
# 12621  Куриные и свиные кости залить кипятком (5 л), ...
#
#                                               ingredient  \
# 12621  Куриные кости : 1 кг, Свиные кости: 1 кг, Имби...
#
#                                                   energy          time_cook  \
# 12621  Калорий 1178 ккал, Белки 68 грамм, Жиры 82 гра...  Европейская кухня
#
#       type_kitchen           label
# 12621     45 минут  Основное блюдо

# %%
rating = get_recommendation(text_input, model, items_embed, df_items)
df_items.iloc[rating].head()
# Out:
#                                         name  \
# 12621                Говядина в пяти специях
# 13919                    Говядина по-японски
# 17149  Говядина с грецкими орехами и грибами
# 10260    Говядина в томатном соусе с фасолью
# 14534         Говядина с картофелем в рукаве
#
#                                                     text  \
# 12621  Куриные и свиные кости залить кипятком (5 л), ...
# 13919  Говядину хорошо промыть, положить в ёмкость, з...
# 17149  Говядину отварить в под солёной воде до готовн...
# 10260  Нарежьте говядину небольшими кусочками. Обжарь...
# 14534  Картофель почистить, промыть под проточной вод...
#
#                                               ingredient  \
# 12621  Куриные кости : 1 кг, Свиные кости: 1 кг, Имби...
# 13919  Говядина без кости: 1 кг, Капуста: 1 кг, Репча...
# 17149  Говядина: 1 кг, Грецкие орехи: 100 г, Грибы: 3...
# 10260  Говядина: 700 г, Помидоры: 3 штуки, Консервиро...
# 14534  Говядина: 500 г, Картофель: 500 г, Морковь: 1 ...
#
#                                                   energy           time_cook  \
# 12621  Калорий 1178 ккал, Белки 68 грамм, Жиры 82 гра...   Европейская кухня
# 13919  Калорий 736 ккал, Белки 56 грамм, Жиры 46 грам...      Японская кухня
# 17149  Калорий 624 ккал, Белки 44 грамм, Жиры 48 грам...       Русская кухня
# 10260  Калорий 655 ккал, Белки 41 грамм, Жиры 45 грам...  Мексиканская кухня
# 14534  Калорий 414 ккал, Белки 28 грамм, Жиры 21 грам...       Русская кухня
#
#           type_kitchen           label
# 12621         45 минут  Основное блюдо
# 13919  1 час  10 минут  Основное блюдо
# 17149  1 час  10 минут  Основное блюдо
# 10260            1 час  Основное блюдо
# 14534            1 час  Основное блюдо

# %% [markdown]
# Третья рекомендация

# %%
idx = np.random.randint(df_items.shape[0])
text_input = " ".join(df_items.iloc[idx, [0, 2, 3, 4, 5]].values.tolist())
text_input = preproccesing(text_input, tokenizer)
df_items.iloc[[idx]].head()
# Out:
#                           name  \
# 6177  Форшмак «Дружба народов»
#
#                                                    text  \
# 6177  Почистить селедку, или купить готовое филе в м...
#
#                                              ingredient  \
# 6177  Морковь: 1 штука, Плавленый сырок: 3 штуки, Фи...
#
#                                                  energy          time_cook  \
# 6177  Калорий 277 ккал, Белки 21 грамм, Жиры 14 грам...  Европейская кухня
#
#      type_kitchen    label
# 6177     20 минут  Закуска

# %%
rating = get_recommendation(text_input, model, items_embed, df_items)
df_items.iloc[rating].head()
# Out:
#                           name  \
# 6177  Форшмак «Дружба народов»
# 2523                   Форшмак
# 3517      Форшмак классический
# 7296      Форшмак классический
# 3796      Форшмак Лары Кацовой
#
#                                                    text  \
# 6177  Почистить селедку, или купить готовое филе в м...
# 2523  Отрезать от батона — можно обычного нарезного ...
# 3517  Сварить яйца вкрутую. Сельдь нарезать небольши...
# 7296  Филе сельди вымочить в стакане молока в течени...
# 3796  Мелко нарезать лук-шалот. Снять корки со сверд...
#
#                                              ingredient  \
# 6177  Морковь: 1 штука, Плавленый сырок: 3 штуки, Фи...
# 2523  Филе сельди: 500 г, Куриное яйцо: 3 штуки, Бел...
# 3517  Филе соленой сельди: 400 г, Репчатый лук: 100 ...
# 7296  Филе сельди: 4 штуки, Молоко: 225 мл, Яблоко: ...
# 3796  Слабосоленая сельдь: 2 штуки, Сливочное масло:...
#
#                                                  energy          time_cook  \
# 6177  Калорий 277 ккал, Белки 21 грамм, Жиры 14 грам...  Европейская кухня
# 2523  Калорий 227 ккал, Белки 18 грамм, Жиры 13 грам...    Еврейская кухня
# 3517  Калорий 448 ккал, Белки 21 грамм, Жиры 37 грам...    Еврейская кухня
# 7296  Калорий 432 ккал, Белки 29 грамм, Жиры 27 грам...    Еврейская кухня
# 3796  Калорий 485 ккал, Белки 204 грамм, Жиры 37 гра...  Европейская кухня
#
#      type_kitchen    label
# 6177     20 минут  Закуска
# 2523     15 минут  Закуска
# 3517     30 минут  Закуска
# 7296     30 минут  Закуска
# 3796     15 минут  Закуска

# %% [markdown]
# Четвертая рекомендация

# %%
idx = np.random.randint(df_items.shape[0])
text_input = "Ризотто"
print(text_input)
text_input = preproccesing(text_input, tokenizer)
# Out:
# Ризотто

# %%
rating = get_recommendation(text_input, model, items_embed, df_items)
df_items.iloc[rating].head()
# Out:
#                                            name  \
# 20093                Ризотто с мускатной тыквой
# 20078  Ризотто с осьминогом (Risotto con polpo)
# 20100          Ризотто со шпинатом и пармезаном
# 20127         Ризотто с грушей и сыром пекорино
# 20022                        Ризотто с редиской
#
#                                                     text  \
# 20093  Обжарьте лук с 1 ст. л. до мягкости (не допуск...
# 20078  Мясо осьминога промыть и варить в кипящей воде...
# 20100  Растопите в сковороде половину сливочного масл...
# 20127  Очистите грушу, удалите сердцевину. Отложите н...
# 20022  В глубоком и широком сотейнике растопить сливо...
#
#                                               ingredient  \
# 20093  Репчатый лук: 1 головка, Оливковое масло: по в...
# 20078  Осьминог: 1 кг, Рис: 500 г, Белое сухое вино: ...
# 20100  Рис карнароли: 200 г, Шпинат: 200 г, Сливочное...
# 20127  Груши: 1 штука, Лимонный сок: 1 столовая ложка...
# 20022  Редис: 100 г, Рис арборио: 400 г, Чеснок: 2 зу...
#
#                                                   energy          time_cook  \
# 20093  Калорий 326 ккал, Белки 12 грамм, Жиры 6 грамм...  Европейская кухня
# 20078  Калорий 785 ккал, Белки 54 грамм, Жиры 16 грам...  Итальянская кухня
# 20100  Калорий 342 ккал, Белки 9 грамм, Жиры 17 грамм...  Итальянская кухня
# 20127  Калорий 610 ккал, Белки 11 грамм, Жиры 38 грам...  Итальянская кухня
# 20022  Калорий 655 ккал, Белки 19 грамм, Жиры 26 грам...  Итальянская кухня
#
#       type_kitchen    label
# 20093     45 минут  Ризотто
# 20078     50 минут  Ризотто
# 20100     40 минут  Ризотто
# 20127     30 минут  Ризотто
# 20022     30 минут  Ризотто

# %% [markdown]
# Пятая рекомендация

# %%
idx = np.random.randint(df_items.shape[0])
text_input = "Блинчики с вараньем"
print(text_input)
text_input = preproccesing(text_input, tokenizer)
# Out:
# Блинчики с вараньем

# %%
rating = get_recommendation(text_input, model, items_embed, df_items)
df_items.iloc[rating].head()
# Out:
#                                                     name  \
# 1233                         Блинчики с плавленным сыром
# 1082                       Блинчики из отрубей по Дюкану
# 29152                                Блинчики из отрубей
# 34454                       Яичные блинчики с креветками
# 1131   Яичные блинчики с помидорами, зеленью, чесноко...
#
#                                                     text  \
# 1233   Блинчики можно купить уже готовые, а можно вып...
# 1082   Отруби смолоть в кофемолке или блендере в муку...
# 29152  Смешать отруби, творог и яйцо (или только его ...
# 34454  Креветки промыть, добавить нашинкованный лук, ...
# 1131   Яйца, молоко, зелень, соль взбиваем и выпекаем...
#
#                                               ingredient  \
# 1233   Тонкие блины : 3 штуки, Плавленый сыр: 6 штук,...
# 1082   Овсяные отруби: 2 столовые ложки, Пшеничные от...
# 29152  Отруби: 60 г, Мягкий обезжиренный творог: 1,5 ...
# 34454  Очищенные креветки: 100 г, Куриное яйцо: 4 шту...
# 1131   Куриное яйцо: 1 штука, Молоко: 30 мл, Соль: по...
#
#                                                   energy          time_cook  \
# 1233   Калорий 3197 ккал, Белки 205 грамм, Жиры 142 г...      Русская кухня
# 1082   Калорий 182 ккал, Белки 14 грамм, Жиры 8 грамм...  Европейская кухня
# 29152  Калорий 187 ккал, Белки 19 грамм, Жиры 9 грамм...      Русская кухня
# 34454  Калорий 274 ккал, Белки 10 грамм, Жиры 20 грам...              Блины
# 1131   Калорий 282 ккал, Белки 11 грамм, Жиры 24 грам...      Русская кухня
#
#       type_kitchen    label
# 1233       5 минут  Завтрак
# 1082      25 минут  Завтрак
# 29152     10 минут  Выпечка
# 34454     35 минут  Выпечка
# 1131      25 минут  Завтрак
